# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("D:/hotel.csv")

# %%
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
data.shape
# Out:
# (119390, 32)

# %%
data.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
data.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
data.isna().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
data1 = data.dropna(axis=1, thresh= 59695)

# %%
data1.isnull().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             488
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
data1.iloc[:,10]= data.fillna(data.iloc[:,10].mean())

# %%
data1.isnull().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              0
# babies                                0
# meal                                  0
# country                             488
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
data1.iloc[:,13]= data.fillna(data1.iloc[:,13].mode()[0])

# %%
data1.isnull().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              0
# babies                                0
# meal                                  0
# country                               0
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
data1.iloc[:,23] = data1.fillna(data1.iloc[:,23].mode()[0])

# %%
data1.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# days_in_waiting_list              0
# customer_type                     0
# ...

# %%
data1.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
data1
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
data1[["lead_time","adults","children","babies","agent","adr"]].mean()
# Out:
# lead_time    104.011416
# adults         1.856403
# babies         0.007949
# adr          101.831122
# dtype: float64

# %%
data1[["lead_time","adults","children","babies","agent","adr"]].std()
# Out:
# lead_time    106.863097
# adults         0.579261
# babies         0.097436
# adr           50.535790
# dtype: float64

# %%
data[["lead_time","adults","children","babies","agent","adr"]].max()
# Out:
# lead_time     737.0
# adults         55.0
# children       10.0
# babies         10.0
# agent         535.0
# adr          5400.0
# dtype: float64

# %%
data[["lead_time","adults","children","babies","agent","adr"]].min()
# Out:
# lead_time    0.00
# adults       0.00
# children     0.00
# babies       0.00
# agent        1.00
# adr         -6.38
# dtype: float64

# %% [markdown]
# Kategori berdasarkan kolom lead time :
# Long : > 100
# Medium : 50-100
# Short : < 50

# %%
data1.iloc[:,2]
# Out:
# 0         342
# 1         737
# 2           7
# 3          13
# 4          14
#          ...
# 119385     23
# 119386    102
# 119387     34
# 119388    109
# 119389    205
# Name: lead_time, Length: 119390, dtype: int64

# %%
data1["Time"] = np.where(data1["lead_time"] > 100 , "Long", np.where(data1["lead_time"] >= 50 ,"Medium","Short" ))

# %%
data1.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ... deposit_type  \
# 0                        0                     0       2  ...   No Deposit
# ...

# %% [markdown]
# Filter all data which has reservation_status_date in >2017

# %%
data1["reservation_status_date"] = pd.to_datetime(data1["reservation_status_date"])

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119390 non-null  object
#  11  babies                          119390 non-null  int64
# ...

# %%
reservation_2017 = data1.loc[data1["reservation_status_date"] > "2016-12-31" , ["reservation_status_date"]]

# %%
reservation_2017["reservation_status_date"].mode()[0]
# Out:
# Timestamp('2017-01-24 00:00:00')

# %%
reservation_2017.describe(include="all", datetime_is_numeric="True")
# Out:
#              reservation_status_date
# count                          36483
# mean   2017-04-24 13:45:36.189458176
# min              2017-01-01 00:00:00
# 25%              2017-02-23 00:00:00
# 50%              2017-04-22 00:00:00
# 75%              2017-06-22 00:00:00
# max              2017-09-14 00:00:00

# %% [markdown]
# Visualize the arrival_date_month to see in what month the most visitors come

# %%
arrival_date = data1["arrival_date_month"]
arrival_date
# Out:
# 0           July
# 1           July
# 2           July
# 3           July
# 4           July
#            ...
# 119385    August
# 119386    August
# 119387    August
# 119388    August
# 119389    August
# Name: arrival_date_month, Length: 119390, dtype: object

# %%
data1.loc[:,"arrival_date_month"]
# Out:
# 0           July
# 1           July
# 2           July
# 3           July
# 4           July
#            ...
# 119385    August
# 119386    August
# 119387    August
# 119388    August
# 119389    August
# Name: arrival_date_month, Length: 119390, dtype: object

# %%
data1.loc[:,"arrival_date_month"].value_counts()
# Out:
# August       13877
# July         12661
# May          11791
# October      11160
# April        11089
# June         10939
# September    10508
# March         9794
# February      8068
# November      6794
# December      6780
# January       5929
# Name: arrival_date_month, dtype: int64

# %%
data1.loc[:,"arrival_date_month"].mode()[0]
# Out:
# 'August'

# %%
data1.loc[:,"arrival_date_month"]
# Out:
# 0           July
# 1           July
# 2           July
# 3           July
# 4           July
#            ...
# 119385    August
# 119386    August
# 119387    August
# 119388    August
# 119389    August
# Name: arrival_date_month, Length: 119390, dtype: object

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119390 non-null  object
#  11  babies                          119390 non-null  int64
# ...

# %%
from collections import Counter

# %%
arrival_date_month = data1["arrival_date_month"] 

arrivaldatemonth = Counter()

# %%
for arrivaldate in arrival_date_month:
    arrivaldatemonth.update(arrivaldate.split(';'))
    
print(arrivaldatemonth.most_common())
# Out:
# [('August', 41631), ('July', 37983), ('May', 35373), ('October', 33480), ('April', 33267), ('June', 32817), ('September', 31524), ('March', 29382), ('February', 24204), ('November', 20382), ('December', 20340), ('January', 17787)]

# %%
month=[]
qty = []

for item in arrivaldatemonth.most_common():
    month.append(item[0])
    qty.append(item[1])

print(month)
print(qty)
# Out:
# ['August', 'July', 'May', 'October', 'April', 'June', 'September', 'March', 'February', 'November', 'December', 'January']
# [41631, 37983, 35373, 33480, 33267, 32817, 31524, 29382, 24204, 20382, 20340, 17787]

# %%
plt.bar(month, qty , color="b")

plt.style.use("seaborn")
plt.title("Month of The Most Visitor Come")
plt.xlabel("Number of Visitors")
plt.ylabel("Month")
plt.tight_layout()

plt.savefig("D:/Most.png")
plt.show()

# %%
time = data1["Time"] 

SpecTime = Counter()

# %%
for specttime in time:
    SpecTime.update(specttime.split(';'))
    
print(SpecTime.most_common())
# Out:
# [('Short', 50281), ('Long', 47360), ('Medium', 21749)]

# %%
Time=[]
Spec = []

for item in SpecTime.most_common():
    Time.append(item[0])
    Spec.append(item[1])

print(Time)
print(Spec)
# Out:
# ['Short', 'Long', 'Medium']
# [50281, 47360, 21749]

# %%
colors = ["green","red","yellow"]
explode = [0,0,0]

plt.style.use("seaborn")
labels= ["Short", "Long", "Medium"]
plt.pie(Spec , labels=labels , autopct="%1.2f%%", colors=colors, explode=explode)
plt.title(" Lead Time Categories")
plt.tight_layout()

plt.savefig("D:/LeadTimeCategories.png")
plt.show()

# %%
data1["reservation_status_date"]
# Out:
# 0        2015-07-01
# 1        2015-07-01
# 2        2015-07-02
# 3        2015-07-02
# 4        2015-07-03
#             ...
# 119385   2017-09-06
# 119386   2017-09-07
# 119387   2017-09-07
# 119388   2017-09-07
# 119389   2017-09-07
# Name: reservation_status_date, Length: 119390, dtype: datetime64[ns]
